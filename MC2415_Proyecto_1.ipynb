# %% [markdown]
# <!-- Create the front page -->
#
# <!-- Load the USB logo -->
# <center><img crossorigin="anonymous" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/USB_logo.svg/800px-USB_logo.svg.png" class="svg" width="150" ><center>
#
# <!-- Put the letterhead -->
# <h5><center>UNIVERSIDAD SIMÓN BOLÍVAR</center></h5>
# <h5><center>DEPARTAMENTO DE MECÁNICA</center></h5>
# <h5><center>VIBRACIONES MECÁNICAS MC-2415</center></h5>
# <h5><center>PROFESOR: BORIS BOSSIO</center></h5>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <!-- Title -->
# <h5><center><b>PROYECTO 1. MODELADO DE UN SISTEMA MASA RESORTE AMORTIGUADOR<b></center></h5>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <!-- Student information and date -->
# <h5><center>Realizado por:</center></h5>
# <h5><center>15-10725 Inojosa Steven:</center></h5>
# <br>
# <h5><center>Sartenejas, Junio 2022</center></h5>

# %% [markdown]
# <h5><b> Problema 1 </b><br>
# Objetivo: Modelar y encontrar la respuesta del sistema mostrado en la figura 1.<br>
# Se aprecia una masa de 1 kg, vinculada vinculada a tierra por medio de un resorte de constante K = 1 N/m y de un amortiguador de constante c, con condiciones iniciales $v_0=0$ m/s; $y_0=-0,1$ m. <br>
# Usted debe considerar dos casos para encontrar la respuesta de su modelo: Caso A) y Caso $\zeta=0$ y B) $\zeta=0,02$. <br>
# Para cada caso: <br></h5>
#
#
# *   Muestre la ecuación de movimiento del sistema e indique cuál(es) método(s) numérico(s) fue(ron) empleado(s) para obtener la respuesta del sistema.
# *   Grafique la posición y la velocidad absoluta de la masa en función del tiempo (para $0 < t < 10s$), considerando las condiciones iniciales indicadas (medidas a partir de la posición de equilibrio estable (p.e.e.).
#
# <!-- Insert figure -->
# <center><b>Figura 1. Sistema masa-resorte-amortiguador.<b></center>
# <center><img src="https://drive.google.com/uc?export=view&id=1Geps7bkgfaHLtUGdejpRZwGwTtmsIalj" width="300"></center><br><br>
#
# <h5><b> Problema 2 </b><br>
# <h5> Objetivo: Modelar y encontrar la respuesta del sistema mostrado en la figura 2. <br>
# Se aprecia una masa de 1 kg, vinculada vinculada a tierra por medio de un resorte de constante K = 1 N/m y de un amortiguador de constante c, con condiciones iniciales $v_0=0$ m/s; $y_0=-0,1$ m. <br>
# Usted debe considerar dos casos para encontrar la respuesta de su modelo: Caso A) y Caso $\zeta=0$ y B) $\zeta=0,02$. <br>
# Para cada caso:
#
# * Muestre la ecuación de movimiento del sistema e indique cuál(es) método(s) numérico(s) fue(ron) empleado(s) para obtener la respuesta del sistema.
# * Grafique la posición y la velocidad absoluta de la masa en función del tiempo (para $0 < t < 10s$), considerando las condiciones iniciales indicadas (medidas a partir de la posición de equilibrio estable (p.e.e.) y que $F(t)=F_0sin(\Omega t)$.
